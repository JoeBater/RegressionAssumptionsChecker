# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\user\ML\Classification\deep drill\42452_2021_4769_MOESM1_ESM (1).xlsx')
df
# Out:
#        HoleSection  M.Depth  RateofPenetration  WeightonBit  Rotation  Torque  \
# 0             17.5      823           4.081633      30.8000    139.00  4.3000
# 1             17.5      824           4.545455      35.2000    119.00  4.3000
# 2             17.5      825           5.172414      32.9000    117.00  4.4000
# 3             17.5      826           8.333333      25.2000    121.00  3.9000
# 4             17.5      827           7.594937      32.0000    129.00  4.3000
# ...            ...      ...                ...          ...       ...     ...
# 65371          8.5     3976           3.186000       7.6846    202.18  3.1006
# 65372          8.5     3977           3.264000       8.1510    202.04  3.1450
# 65373          8.5     3978           3.894000      11.5368    201.56  3.2190
# 65374          8.5     3979           4.458000      11.0968    201.31  3.2190
# 65375          8.5     3980           6.498000       9.9352    201.48  3.2486
#
# ...

# %%
from ClassificationAssumptionsChecker import ClassificationAssumptionsChecker
checker = ClassificationAssumptionsChecker(df, target="LossesSeverity", algorithm="LogisticRegression")

assumptions = checker.check_assumptions()
checker.report_assumptions()
checker.recommend_models()
# Out:
# 🔍 Assumption Diagnostics Report
# ...
#
# 🧠 Multicollinearity
# ------------------------------
# multicollinearity: False
# details: [{'feature': 'M.Depth', 'VIF': 4.642464286188781}, {'feature': 'RateofPenetration', 'VIF': 1.5551790724944727}, {'feature': 'WeightonBit', 'VIF': 3.861232555176377}, {'feature': 'Torque', 'VIF': 4.262260947494185}, {'feature': 'PlasticViscosity', 'VIF': 6.033455561635527}, {'feature': 'Gel Strength10sec', 'VIF': 5.1293662463271055}]
# notes: Perfect or high multicollinearity detected
# recommendation: High or perfect multicollinearity detected. Consider removing these features: ['FlowIn', 'MudWeight', 'FunnelViscosity', 'PumpStroke', 'Gel Strength10min', 'YieldPoint', 'Solid', 'StandpipePressure', 'HoleSection', 'Rotation', 'FlowOut']
# drop_set: ['FlowIn', 'MudWeight', 'FunnelViscosity', 'PumpStroke', 'Gel Strength10min', 'YieldPoint', 'Solid', 'StandpipePressure', 'HoleSection', 'Rotation', 'FlowOut']
#
# 🧠 Class Imbalance
# ------------------------------
# ...
