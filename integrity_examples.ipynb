# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\ML\Classification\arrhythmia\arrhythmia_dirty.csv')
df
# Out:
#      Age  Sex  Height  Weight  QRS_duration  P-R_interval  Q-T_interval  \
# 0     75    0     190      80            91           193           371
# 1     56    1     165      64            81           174           401
# 2     54    0     172      95           138           163           386
# 3     55    0     175      94           100           202           380
# 4     75    0     190      80            88           181           360
# ..   ...  ...     ...     ...           ...           ...           ...
# 447   53    1     160      70            80           199           382
# 448   37    0     190      85           100           137           361
# 449   36    0     166      68           108           176           365
# 450   32    1     155      55            93           106           386
# 451   78    1     160      70            79           127           364
#
#      T_interval  P_interval  QRS_vector_angle  ... Unnamed: 270 Unnamed: 271  \
# ...

# %%
from DataIntegrityChecker import DataIntegrityChecker
checker = DataIntegrityChecker(df)
checker.run_all_checks()
print(checker.report())

for line in checker.recommended_actions():
    print(line)
# Out:
# ⚠️ missingness: Missingness detected in 1 columns and 0 rows. Top columns: `J_vector_angle` (83.2%).
# ⚠️ white_space: Whitespace issues detected and fixed in 5 columns. Top columns: `J_vector_angle` (null-like: 376, lead: 0, trail: 0), `P_vector_angle` (null-like: 22, lead: 0, trail: 0), `T_vector_angle` (null-like: 8, lead: 0, trail: 0), `QRST_vector_angle` (null-like: 1, lead: 0, trail: 0), `Heart_rate` (null-like: 1, lead: 0, trail: 0).
# ⚠️ constancy: 17 constant and 60 near-constant columns detected. 17 constant columns: `DI_S'_wave`, `AVL_Number_of_intrinsic_deflections`, `AVL_Existence_of_diphasic_derivation_of_R_wave`, `AVF_Existence_of_diphasic_derivation_of_P_wave`, `V4_Existence_of_diphasic_derivation_of_T_wave`; Near-constant columns: `DI_Existence_of_ragged_R_wave` (99.8%), `DII_Existence_of_ragged_P_wave` (99.8%), `DIII_Existence_of_ragged_R_wave` (99.8%), `DIII_Existence_of_ragged_P_wave` (99.8%), `AVR_S'_wave` (99.8%)
# ...

# %%
df = pd.read_excel(r'C:\Users\user\ML\Regression\container-tracking\Container Tracking Data.xlsx')
df
# Out:
#      CONTAINER_NUMBER         VESSEL_NAME FREIGHT_FORWARDER  \
# 0         FCIU8573349         CAPE SOUNIO               CIF
# 1         TGBU9903815         CAPE SOUNIO               CIF
# 2         TCNU3242533     OOCL LUXEMBOURG             Axiom
# 3         FCIU8623774           MSC ORION                LF
# 4         FCIU9776905       COSCO ENGLAND               CIF
# ...               ...                 ...               ...
# 1825      FSCU6353914  PEARL RIVER BRIDGE               JAS
# 1826      MAGU5225236     CSCL YELLOW SEA          Art Time
# 1827      BEAU4698279             AS SARA                LF
# 1828      CAIU9631734         CSCL SUMMER          YUEHSNEG
# 1829      TGHU9306386         OOCL TAIPEI             Axiom
#
#                                 PLACE_OF_DISPATCH  \
# 0                 Yantian, Guangdong Sheng, China
# 1                 Yantian, Guangdong Sheng, China
# 2                   Shanghai, Shanghai Shi, China
# ...

# %%
from DataIntegrityChecker import DataIntegrityChecker
checker = DataIntegrityChecker(df)
checker.run_all_checks()
print(checker.report())

for line in checker.recommended_actions():
    print(line)
# Out:
# ⚠️ missingness: Missingness detected in 1 columns and 53 rows. Top columns: `Another NEW Predicated Delivery Date` (100.0%). 53 rows exceed missingness threshold.
# ⚠️ white_space: Whitespace issues detected and fixed in 2 columns. Top columns: `Another NEW Predicated Delivery Date` (null-like: 1830, lead: 0, trail: 0), `CONTAINER_NUMBER` (null-like: 0, lead: 0, trail: 1).
# ⚠️ constancy: 2 constant and 0 near-constant columns detected. 2 constant columns: `DELIVERED_FLAG`, `Another NEW Predicated Delivery Date`
# ⚠️ cardinality: 1 high-cardinality columns detected.
# ✅ duplicated_rows: No duplicated rows found.
# ⚠️ embedded_rows: 1 embedded row-like cells detected.
# # MISSINGNESS recommendations:
# # Consider imputing or dropping columns with high missingness
# # Column `Another NEW Predicated Delivery Date` has 100.0% missing
# ...
